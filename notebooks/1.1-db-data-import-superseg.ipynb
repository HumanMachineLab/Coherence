# %%
# Run if working locally
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sqlite3
from sqlite3 import Error
import pickle
import os, sys
import config

config.root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, config.root_path)

from src.dataset.dataset import RawData
from src.dataset.wikisection_preprocessing import (
    tokenize,
    clean_sentence,
    preprocess_text_segmentation,
    format_data_for_db_insertion,
    remove_blank_sentence,
    flatten_list,
)
from db.dbv2 import DB, Table, TestTable, ValidationTable

# %%
dataset_type = "city"

# %%
dataset = RawData(dataset_type)

data = dataset.get_superseg_data(split="train")
# cleaned_data = preprocess_text_segmentation(data)

# %%
data
# Out:
# {'dial_data': {'superseg-v2': [{'dial_id': '0c0dd5a4a1dfb23135eec6b77bca2fd5',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': "I'm looking for information regarding benefits planning, can you help me?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you planning for your own future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Yes I am',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'You need to think about what your family would do if you died now. Social Security can help your family, provided you have earned enough Social Security credits through your work',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'What are Social Security credits?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'They are credits earned through your work and when you pay Social Security',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "What happens if the amount of spouse's benefit on my record is more than the widow's or widower's benefit on my Social Security record?",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "Is that's the case, they'll receive a combination of benefits which will total the higher amount in this instance",
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': "What happens if I don't have enough credits built up, do my children or spouse receive anything?",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'Your children and spouse can get benefits if you have credits built up for one and one-half years of work 6 credits in the three years just before your death',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'What if my surviving divorced spouse remarries?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': 'They will continue to receive benefits on your Social Security record',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 13,
#       'utterance': 'What if my surviving spouse will be in receipt of a non-Social Security pension in the future, are their benefits going to be affected?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 14,
#       'utterance': 'In this case, their benefits as a survivor may be affected, depending on what they will receive',
#       'topic_id': 3,
#       'segmentation_label': 0}]},
#    {'dial_id': '7a4081e652ab04c91dbfdbd38f844772',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Can you help me with planing the benefits for my survivors?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you planning for the future of your survivors?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Not right now.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'But I want to know if my family would get any help from Social Security after my passing.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'yes, Social Security can help your family if you have earned enough credits through your work.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'And what about my widow, what benefits would she receive?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': "She can get reduced benefits as early as age 60 or full benefits at full retirement age. If she's 50 years old she could get the benefits if she's disabled and her disability started 7 years or earlier before your death.",
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'what if she remarries after my death?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'if she remarries after age 60, 50 if disabled, she would still qualify for the benefits on your social security records.',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'And if she receives a pension not covered by Social Security?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': "If it's a pension based on work then their Social Security benefits as a survivor could be affected.",
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': '6a15eda0180de1f506d7dff29e312e07',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'I need help planning for my survivors.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you currently planning for the future of your survivors?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Yes, I am.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'If you have earned enough Social Security credits, then Social Security can help your family should you die now.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'Can my stepfather receive the benefits too?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'He can if he became your stepfather before you turned 16.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'How much my family members can get from the benefits?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "there's a limit to the amount they can receive each month, but it varies. Normally is equal to between 150 and 180 percent of the basic benefit rate.",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'is the sum payable to your family members greater than this limit?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': "no, it isn't",
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'Tell me about the credits I can earn through Social Security.',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': 'You can get up to four credits each year. You get 1 credit for every 1,360$ you earn during the year.',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 13,
#       'utterance': 'How much money would my survivors receive?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 14,
#       'utterance': "it depends on the average lifetime earnings you get. The higher your earnings the more they'll receive.",
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    {'dial_id': '078d508e4ca21a8c9a4aed7e31b176d3',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'I want to know about planning Social Security benefits for the future in case I die.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you already planning for the future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Yes, I am',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'Since you are already thinking about what your family would need in case you die, I can tell you that Social Security can help your family if you have earned enough credits through your work.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'Tell me some of the things I need to know about it.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'Well, one important thing is to know that there are limits on how much your survivors may earn while they receive the benefits.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'Tell me about what would happen if my surviving divorced wife remarries after my death.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "If she remarries before turning 60 then she won't be able to get the benefits while she is still married.",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': "And what if she qualifies but the amount she could get from her new husband's Social Security benefits are more than what she would receive from mine?",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': "then she should apply for her new husband's benefits and then she would receive a combination of benefits that would amount to be equal to the highest benefits amount.",
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'What if I die before earning enough credits and my widow is still taking care of our children?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': "in that case, your children and widow would still receive the benefits, no matter if you didn't manage to earn enough credits.",
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': 'd917d21c4d8bf6225971f62175d4ea59',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'can you tell me about planning for social security benefits for my survivors?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you currently planning for their future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Not right now.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'But just to know, what if I left a surviving divorced spouse?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'If your marriage lasted for at least 10 years, then they could receive the same benefits as your widow or widower.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'and, would social security actually help my family if I die?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'Yes, if you earn enough social security credits then Social Security would help your survivors with the benefits you earn while working.',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'Could my widow apply for disability benefits after my death?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'She would need to contact Social Security at 1-800-772-1213 . The process could get faster if she completes an Adult Disability Report before her appointment.',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'Please, tell me about the benefits she could get and at what age?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'your widow could get reduced benefits as early as age 60 or full benefits at full retirement age. If she suffers from a disability, she could get the benefits as soon as she turns 50 if the disability started before your death or up to 7 years after your death.',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'What is the maximum amount my family can get from Social Security?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': "It varies, but there's a limit that's generally between 150 and 180 percent of the basic benefit rate.",
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    {'dial_id': '3a5295f45f39e6d1ee2a64b93be18fb9',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Yes maybe you can help me with the forms for benefit planning?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you interested in planning for the future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Yes I would like to prepare in the eventuality that I die.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'If you have earned enough Social Security credits through your work, Social Security can help your family financially.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'Would my partner benefit from this?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'Yes if they have not remarried in the interim and if they take care of your child who is under age 16 or disabled and receives benefits on your record.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'What if my spouse and I are divorced?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': 'Are you divorced from them?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'No we are merely separated.',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'How much is enough credits from work?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'They can get benefits if you have credit for 12 to 18 months of work 6 credits in the three years just before your demise.',
#       'topic_id': 3,
#       'segmentation_label': 0}]},
#    {'dial_id': '8a12e819707b06a358c55779c84e8ffd',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'I need some information on benefits planning.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'I can help you with this. Are you planning for your future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'No, I am planing for my wife Sally.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'If Sally remarries after I die should she apply for my benefits?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'Yes, she can.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'What benefits will Sally get if we divorce before I die?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'So she would be a surviving divorced spouse?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'Yes, just trying to figure out her future without me.',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'Ok, I see. Sally would continue to receive the benefits after your death provided your marriage lasted 10 years or more.',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'I want to make sure that I plan for my family. How do I know if I have earned enough Social Security credits through my work?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'Absolutely, planning for the future is always wise. We can discuss the credit limits.',
#       'topic_id': 3,
#       'segmentation_label': 0}]},
#    {'dial_id': '0e38e6aa49c336bdd1fa3516c271b8ae',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'I want to know how to plan for the social security benefits for my survivors.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Are you currently planning for their future?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Yes, I am',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'then you can rest assured that they will receive Social Security help if you manage to earn enough social security benefits through your work.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'would my wive get the benefits regardless of her age?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': "She would get the benefit no matter her age if she's disabled or it's still taking care of your child who is 16 years old or younger.",
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "what's the minimum amount of credits needed for my wife to get the benefits while she's still taking care of my tuner age children?",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "you'd need to sum at least 6 credits in the three years just before your death",
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'what if the amount my family members get paid is higher than the limits?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': "Then the benefits would be reduced proportionately. Benefits for disabled surviving spouse won't count for the maximum amount.",
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'and what if my widow remarries after turning 60?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': "she'd still be able to receive the surviving benefits on your record.",
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    {'dial_id': 'f6fff0007a5a314a25997206d323da60',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Hi, I want to know how to apply for disabilty benefits for family members.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "You'll need the Social Security numbers of each member of your family that may be eligible for benefits.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'Is your spouse also applying for benefits?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': "No, that's not the case.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'Do you have proof of the marriage?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'Yes, I do.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "What can I do in case I don't have all the required documents?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "If you need the benefits now, don't delay applying for it, we'll help you get all the documents and information needed.",
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'just in case my application is denied. Can I request an appeal?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'we have a free TTY number for people with hearing impairments to request an appeal, 1 - 800 - 325 - 0778.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'what info do I need to give to apply for the benefits?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': "You'll need some personal information and info like your Social Security number and proof of your age, medical records, etc.",
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': '1d8e91e6b3adb0ce56fb514b7b95c0dc',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'I have recently become permanently disabled. How do I apply for Social Security?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'To apply, you will have to provide information about yourself including your Social Security number, information about your health history including doctors names and addresses, dates of any hospital visits, and a list of medication and the dosage you take.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'Do I need to provide any information about the others who live in my home?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'Yes. If any other members of your household qualify for benefits, their social security numbers and proof of their ages will be needed.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'Do I need a proof of marriage if my husband is applying for benefits, as well?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'Yes. A proof of marriage is required if your spouse is applying for benefits too.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "I'm not clear on whether or not I am qualified for benefits. Is there a place where I could get more information about this?",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': 'Yes, more information about this topic can be found in your SSI booklet on page 5 under "Your income and resources".',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'Is there any way that I can get additional help on applying for disability?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'Yes, our Disability Starter Kit is available to all adults and children under 18. This kit will help aid you in getting ready for your online application and disability interview.',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': "If I'm turned down for disability, can I appeal?",
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': 'Yes. You can contact Social Security if you are denied. If you have a hearing disability, you can call toll free at 1-800-0778.',
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    {'dial_id': '73d7676b3a625148871689eb2587230a',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'What can I do if my application for disability benefits is denied?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "We can deny your application if we decide you don't meet the requirements to get the benefits after reviewing your application. But, you have the right to ask for a second review.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': 'So if I disagree with your decision I can ask for y application to be reviewed again?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'Yes, and in the notice you receive after getting your application denied, you can see the instructions on how to appeal the decision.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'and, as a person with hearing problems, do you offer any suitable form of contact?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'yes, we have the toll-free TTY number 1-800-325-0778',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'Can you give me some publications about disability benefits?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': 'Sure, I recommend you read the publications "Apply Online For Disability Benefits", "Disability Benefits" and "Disability Starter Kit".',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'Thanks. And again, about appealing a denied decision. Is there anything to do if my decision is denied a second time?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': "If we decide you don't qualify because you are not disabled according to our rules, you can appeal online.",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'Was your application denied?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': "No, I'm just curious, just in case.",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 13,
#       'utterance': 'now, can you tell me about SSI?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 14,
#       'utterance': "the Supplemental Security Income or SSI it's the option you would get if you didn't manage to get enough Social Security credits to qualify for the disability benefits.",
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': 'a53cc503722ed95bee984c7c2892a93c',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'What can I do if my disability benefits application is denied?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "if your application is denied is due to, after reviewing your case, we decide that you don't meet the requirements for disability benefits. But you can appeal our decision.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'Do you disagree with our decision?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'Yes, what can I do now?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'you have the right to ask for another review. In the denial notification you receive, you can see the instructions to appeal the decision.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': "what would happen if I don't have enough social security credits to qualify for disability benefits?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'In that case, you can still qualify for Supplemental Security Income (SSI) if you have limited income and resources.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'do you have any TTY number for deaf people?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'Yes, we have the toll-free TTY number 1-800-325-0778',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'Can a deaf person request an appeal through that TTY number?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'Yes, they can.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'Where can I get more information about SSI?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': 'You can read our Supplemental Security Income SSI booklet in the section "Your income and resources" on page 5.',
#       'topic_id': 0,
#       'segmentation_label': 0}]},
#    {'dial_id': '10035f3088afb8752e45122736ff8bb1',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'My application has been denied what do I do?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Read if your application is Denied on our website',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'and read  If you disagree with our decision',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'ok',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': 'What other publications are there I can read?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': 'There is Apply Online For Disability Benefitss Disability,  Benefitss  and  Disability Starter Kit',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'My application was denied for non medical reason',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': 'you can appeal our decision online',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'Where can I get more information?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'please read " Your income and resources " on page 5 of our Supplemental Security Income SSI booklet',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'How do I request an appeal?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 12,
#       'utterance': ' call our toll - free number at 1-800-772-1213 to request an appeal and People who are deaf or hard of hearing can call our toll - free TTY number , 1 - 800 - 325 - 0778',
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': '7b005230655179ed08d11d401603dd5e',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'What original documentation do I need to get a Social Security Card for my child?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Firstly we need to establish citizenship',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': "Have you already established your child's US citizenship with us?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'Yes I have',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'The original documentation needed for citizenship is a US birth certificate or US passport',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': "What if I don't inform you of my child's name change?",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'This could delay any tax refund due to you or your child',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': "What is needed if I have already established my child's name with your department?",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'null',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': "Have you changed your child's name on their Social Security card?",
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'No, not yet',
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': '9632a477da49cf3708ba8f5edf488b93',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Hello, I need to get a Corrected Card for my child. Can you help me?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Did you change the name of your child?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': "No, I didn't change his name.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'Does he works?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': "No, he doesn't.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': "You need to tell us when your child's name changes or it could cause him some inconveniences. Your child hasn't changed his name?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "No, he hasn't changed his name.",
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'What could I use as proof of identity to show to Social Security?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': "You could use your U.S. driver's license or a state-issued non-driver identification card.",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'Any other document I could use?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'You can also use your U.S. passport.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'And for my child, what kind of document can I use as his proof of identity?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': "You must use a document that shows his name, identifying info, recent photography, or parents' names.",
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 14,
#       'utterance': 'can I use copies of the documents needed?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 15,
#       'utterance': 'Only if the copies are certified by the agency that issues them. If not, the documents must be originals.',
#       'topic_id': 2,
#       'segmentation_label': 0}]},
#    {'dial_id': '1d94bd54404600ad973a5beeb964ccaf',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Hello. I need information about corrected cards for U.S. born children.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "ok, first, have you changed your child's name?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 3,
#       'utterance': "I haven't",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 4,
#       'utterance': 'Is your child currently working?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': "No, he isn't working.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': "Just so you know, it could cause you inconveniences if you don't tell us about your child's name change.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': "But, I haven't changed my child's name.",
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'What I want to know right now is, what original documents do I need to apply for a corrected card?.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'null',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'have you established with us the citizenship of your child?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 11,
#       'utterance': 'Not yet.',
#       'topic_id': 1,
#       'segmentation_label': 0}]},
#    {'dial_id': '3f5605e9745f5eb32ee4e6f754977c47',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'What documents do I need to obtain a corrected card for my child?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'The documents you need will depend on whether or not your child is a U.S. citizen.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': "Have you established your child's U.S. citizenship with us?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'response_negative',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'No, I have not.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 5,
#       'utterance': "I don't have an identity document for my child with his prior name on it. What can I do?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 6,
#       'utterance': "An unexpired identity document with your child's new name can be accepted as long as we can establish his/her identity in our records.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 7,
#       'utterance': 'What about an expired document with his prior name?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 8,
#       'utterance': "Yes, an expired document with your child's prior name can be accepted.",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 9,
#       'utterance': 'Do I need anything else to prove his identity?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 10,
#       'utterance': 'Yes, other documents will be needed for proof of identity.',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
# ...
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': "Will do. But let's get back to what you first talked about. The counseling at a local Vet Center is free of charge for me, yes?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'Correct. You can get free private counseling, alcohol and drug assessment and other support at one of our 300 community Vet Centers, provided that you are a Veteran.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': "That's great. And outside of that, where could I find more information?",
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': 'You can download our Guide to VA Mental Health Services PDF, or go to our Make the Connection website to hear stories from Veterans about their own experiences with overcoming drug and alcohol problems, and to get access to more resources and support.',
#       'topic_id': 1,
#       'segmentation_label': 0}]},
#    {'dial_id': '1f12f9bfbf292a63cd223354c3d6bbfd',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Hello, I need career information. What do you offer?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "On our page you can view the current subsistence allowance rates to find out the amount we'll provide to help you pay for basic needs like food and clothing if you're an eligible Veteran participating in the Voc Rehab program.",
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'Would you like to learn more about other VA benefits and services?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'Yes, please. Go ahead.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'You can explore options for using GI Bill benefits to help pay for school or training, for example, and find out what benefits you can get.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'Are things like food and clothing covered by the benefits?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': "Yes. We'll help you pay for basic needs like food and clothing if you're an eligible Veteran participating in the Voc Rehab program.",
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'Would it be possible to talk to a real human about this?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'Yes, you can talk to someone at any time.',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'Good. Before we get to that, how can I find the right career for me?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'You can match your interests and skills to a career with a CareerScope assessment. Use this online tool to get recommendations for careers you may enjoy and succeed in, and training programs to help you get started.',
#       'topic_id': 4,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'What else can I do?',
#       'topic_id': 5,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': 'You can apply for a Certificate of Eligibility for a VA direct or VA-backed home loan to build, buy, improve, or refinance a home.',
#       'topic_id': 5,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 14,
#       'utterance': "No. I mean, what can I do if I'm a veteran in need of help?",
#       'topic_id': 6,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 15,
#       'utterance': 'In that case you can connect with our caring, qualified Veterans Crisis Line responders for confidential help. Many of them are Veterans themselves. This service is private, free, and available 24/7.',
#       'topic_id': 6,
#       'segmentation_label': 0}]},
#    {'dial_id': '14c64dc2c4246a5877bad0033cd9f2be',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': "Hey, what's going on?. Look a friend of mine told me about possible employment from VA. Where can i get more information?",
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'Hi there. Those benefits are for those eligible veterans participating in the Voc Rehab program, and includes a certain amount of money for basic needs like food and clothing.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'Beside this, are you interested in to know other VA benefits and services?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'Yeah, that would be nice, thanks.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'Good. On that regard, you have the GI Bill benefits to help you pay for school or training.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'That sounds cool. Hey, i wanted to know, what about if i want to pursue a career?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'Well, you would have to go and match your skills first. You can use Career Scope to do that online and see if you may enjoy and succeed in your career.',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'Terrific. Tell me more, please. What other things can you offer to me?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': "Sure, we have many other educational programs and assistance if you are a veteran, reservist or national guard who doesn't qualify for the post 9/11 GI Bill.",
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'And if i have a disability?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'You may qualify for a benefit.',
#       'topic_id': 4,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'In those other program?',
#       'topic_id': 5,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': 'Yeah.',
#       'topic_id': 5,
#       'segmentation_label': 0}]},
#    {'dial_id': '3253917f6e895ffe637d27a31529abe9',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'Can you give me more information and resources to help?',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': 'If you are an eligible Veteran participating in the Voc Rehab program we will provide to help to pay for basic needs like food and clothing.',
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'What other VA benefits and services are available?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'Yes, I need to know what other VA benefits and services are available.',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'The GI Bill gives you benefits to help pay for school or training.',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'What if I am in crisis as a Veteran?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'You can connect with our caring and qualified Veterans Crisis Line responders for confidential help 24/7 for free.',
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'Can I find out if I am eligible for vocational rehab?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': 'If you have a service-connected disability that prevents you from working, then you can find out if you are eligible.',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'What career and employment assistance could I get?',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'You can get help through programs that teach new skills, help find a job, start a business, get educational counseling for Veterans.',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'Is there some type of VA transition assistance?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': 'Yes, VA transition assistance is available as you separate from the military.  You can explore your career options by joining us at Transition Assistance Program briefing.',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 14,
#       'utterance': 'Is there help for job searching?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 15,
#       'utterance': 'Yes, we can help by searching through Department of Labor Search, help with translating your military skills and experience to civilian jobs, and other resources.',
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    {'dial_id': 'e995c3d30936814f076033ae3de518d6',
#     'turns': [{'da': 'query_condition',
#       'role': 'user',
#       'turn_id': 1,
#       'utterance': 'how do I  get More information and resources',
#       'topic_id': 0,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 2,
#       'utterance': "Subsistence allowance ratesView the current subsistence allowance rates to find out the amount we 'll provide to help you pay for basic needs like food and clothing if you 're an eligible Veteran participating in the Voc Rehab program",
#       'topic_id': 0,
#       'segmentation_label': 1},
#      {'da': 'query_condition',
#       'role': 'agent',
#       'turn_id': 3,
#       'utterance': 'What other benefits and services are there?',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'response_positive',
#       'role': 'user',
#       'turn_id': 4,
#       'utterance': 'yes ok thanks',
#       'topic_id': 1,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 5,
#       'utterance': 'GI Bill benefitsExplore options for using GI Bill benefits to help pay for school or training , and find out what benefits you can get',
#       'topic_id': 1,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 6,
#       'utterance': 'how do I Get career and employment assistance',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 7,
#       'utterance': 'About Vocational Rehabilitation and Employment Chapter 31 programsExplore support - and - services program tracks for Veterans and service members with service - connected disabilities  Our programs can help you learn new skills , find a new job , start a new business , get educational counseling , or return to your former job',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 8,
#       'utterance': 'any other ways?',
#       'topic_id': 2,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 9,
#       'utterance': " EligibilityIf you have a service - connected disability that limits your ability to work or prevents you from working , find out if you 're eligible for vocational rehab",
#       'topic_id': 2,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 10,
#       'utterance': 'any other  Other VA benefits and services',
#       'topic_id': 3,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 11,
#       'utterance': 'Other educational assistance programsIf you re a Veteran , Reservist , or National Guard Soldier who doesn t qualify for the Post-9/11 GI Bill',
#       'topic_id': 3,
#       'segmentation_label': 1},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 12,
#       'utterance': 'How do I manage my carerr?',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 13,
#       'utterance': ' Match your interests and skills to a career with a CareerScope assessmentUse this online tool to get recommendations for careers you may enjoy and succeed in , and training programs to help you get started',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'query_solution',
#       'role': 'user',
#       'turn_id': 14,
#       'utterance': 'how do I  Find VA careers and supportGet support for starting or advancing your career at VA or other federal government departments',
#       'topic_id': 4,
#       'segmentation_label': 0},
#      {'da': 'respond_solution',
#       'role': 'agent',
#       'turn_id': 15,
#       'utterance': ' Find VA careers and supportGet support for starting or advancing your career at VA or other federal government departments',
#       'topic_id': 4,
#       'segmentation_label': 0}]},
#    ...]}}

# %%
print("length before blank sentence removal:", len(flatten_list(cleaned_data)))
non_blank_sentences = [remove_blank_sentence(segment) for segment in cleaned_data]
print("length after blank sentence removal:", len(flatten_list(non_blank_sentences)))
# Out:
# length before blank sentence removal: 92839
# length after blank sentence removal: 92839

# %% [markdown]
# ## Format the Data

# %%
data_to_insert = format_data_for_db_insertion(non_blank_sentences)

# %%
data_to_insert[:5]
# Out:
# [('In spite of appearances, both the Basque form Donostia and the Spanish form San Sebastián have the same meaning of Saint Sebastian. The dona/done/doni element in Basque place-names signifies "saint" and is derived from Latin domine; the second part of Donostia contains a shortened form of the saint\'s name. There are two hypotheses regarding the evolution of the Basque name: one says it was *Done Sebastiáne > Donasa(b)astiai > Donasastia > Donastia > Donostia, the other one says it was *Done Sebastiane > *Done Sebastiae > *Done Sebastie > *Donesebastia > *Donasastia > *Donastia > Donostia.\n',
#   1,
#   None,
#   0),
#  ("The city is in the north of the Basque Autonomous Community, on the southern coast of the Bay of Biscay. San Sebastián's picturesque shoreline makes it a popular beach resort. The seaside environment is enhanced by hilly surroundings that are easily accessible, i.e., Urgull (at the heart of the city by the seashore), romantic Mount Ulia extending east to Pasaia, Mount Adarra rising proud far on the south and Igeldo, overlooking the bay from the west.\nThe city sits at the mouth of the River Urumea, Donostia having been built to a large extent over the river's wetlands during the last two centuries. In fact, the city centre and the districts of Amara Berri and Riberas de Loiola lie on such terrain and the former bed of the river, diverted to its current canalized course in the first half of the 20th century.\n",
#   0,
#   1,
#   1),
#  ('San Sebastián features an oceanic climate (Köppen Cfb) with warm summers and cool winters. Like many cities with this climate, San Sebastián typically experiences cloudy or overcast conditions for the majority of the year, typically with some precipitation. The city averages roughly of precipitation annually, which is fairly evenly spread throughout the year. However, the city is somewhat drier and noticeably sunnier in the summer months, experiencing on average approximately of precipitation during those months. Average temperatures range from in January to in August.\n',
#   0,
#   1,
#   2),
#  ('The first evidence of human stationary presence in the current city is the settlement of Ametzagaña, between South Intxaurrondo and Astigarraga. The unearthed remains, such as carved stone used as knives to cut animal skin, date from 24,000 to 22,000 BC. The open-air findings of the Upper Paleolithic have revealed that the settlers were hunters and Homo sapiens, besides pointing to a much colder climate at the time.\n',
#   0,
#   1,
#   3),
#  ('San Sebastián is thought to have been in the territory of the Varduli in Roman times. east of the current city lay the Basque Roman town of Oiasso (Irun), which was for a long time wrongly identified with San Sebastián.\n',
#   0,
#   1,
#   4)]

# %% [markdown]
# ## Iterative Import
# Because I'm going to sleep...

# %%
for dataset_type in ["city", "disease"]:
    database = r"{}/db/{}.db".format(config.root_path, dataset_type)

    for split in ["test", "train", "validation"]:
        dataset = RawData(dataset_type)

        data = dataset.get_data(split=split)
        cleaned_data = preprocess_text_segmentation(data)
        non_blank_sentences = [
            remove_blank_sentence(segment) for segment in cleaned_data
        ]

        data_to_insert = format_data_for_db_insertion(non_blank_sentences)

        if split == "test":
            table = TestTable(dataset_type)
        elif split == "validation":
            table = ValidationTable(dataset_type)
        else:
            table = Table(dataset_type)

        for i, sentence in enumerate(data_to_insert):
            sentence_id = table.create_sentence(sentence)
            if i % 500 == 0:
                print(f"Entered {i} sentences...")
# Out:
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...
# Entered 3000 sentences...
# Entered 3500 sentences...
# Entered 4000 sentences...
# Entered 4500 sentences...
# Entered 5000 sentences...
# Entered 5500 sentences...
# Entered 6000 sentences...
# Entered 6500 sentences...
# Entered 7000 sentences...
# Entered 7500 sentences...
# Entered 8000 sentences...
# Entered 8500 sentences...
# Entered 9000 sentences...
# Entered 9500 sentences...
# Entered 10000 sentences...
# Entered 10500 sentences...
# Entered 11000 sentences...
# Entered 11500 sentences...
# Entered 12000 sentences...
# Entered 12500 sentences...
# Entered 13000 sentences...
# Entered 13500 sentences...
# Entered 14000 sentences...
# Entered 14500 sentences...
# Entered 15000 sentences...
# Entered 15500 sentences...
# Entered 16000 sentences...
# Entered 16500 sentences...
# Entered 17000 sentences...
# Entered 17500 sentences...
# Entered 18000 sentences...
# Entered 18500 sentences...
# Entered 19000 sentences...
# Entered 19500 sentences...
# Entered 20000 sentences...
# Entered 20500 sentences...
# Entered 21000 sentences...
# Entered 21500 sentences...
# Entered 22000 sentences...
# Entered 22500 sentences...
# Entered 23000 sentences...
# Entered 23500 sentences...
# Entered 24000 sentences...
# Entered 24500 sentences...
# Entered 25000 sentences...
# Entered 25500 sentences...
# Entered 26000 sentences...
# Entered 26500 sentences...
# Entered 27000 sentences...
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...
# Entered 3000 sentences...
# Entered 3500 sentences...
# Entered 4000 sentences...
# Entered 4500 sentences...
# Entered 5000 sentences...
# Entered 5500 sentences...
# Entered 6000 sentences...
# Entered 6500 sentences...
# Entered 7000 sentences...
# Entered 7500 sentences...
# Entered 8000 sentences...
# Entered 8500 sentences...
# Entered 9000 sentences...
# Entered 9500 sentences...
# Entered 10000 sentences...
# Entered 10500 sentences...
# Entered 11000 sentences...
# Entered 11500 sentences...
# Entered 12000 sentences...
# Entered 12500 sentences...
# Entered 13000 sentences...
# Entered 13500 sentences...
# Entered 14000 sentences...
# Entered 14500 sentences...
# Entered 15000 sentences...
# Entered 15500 sentences...
# Entered 16000 sentences...
# Entered 16500 sentences...
# Entered 17000 sentences...
# Entered 17500 sentences...
# Entered 18000 sentences...
# Entered 18500 sentences...
# Entered 19000 sentences...
# Entered 19500 sentences...
# Entered 20000 sentences...
# Entered 20500 sentences...
# Entered 21000 sentences...
# Entered 21500 sentences...
# Entered 22000 sentences...
# Entered 22500 sentences...
# Entered 23000 sentences...
# Entered 23500 sentences...
# Entered 24000 sentences...
# Entered 24500 sentences...
# Entered 25000 sentences...
# Entered 25500 sentences...
# Entered 26000 sentences...
# Entered 26500 sentences...
# Entered 27000 sentences...
# Entered 27500 sentences...
# Entered 28000 sentences...
# Entered 28500 sentences...
# Entered 29000 sentences...
# Entered 29500 sentences...
# Entered 30000 sentences...
# Entered 30500 sentences...
# Entered 31000 sentences...
# Entered 31500 sentences...
# Entered 32000 sentences...
# Entered 32500 sentences...
# Entered 33000 sentences...
# Entered 33500 sentences...
# Entered 34000 sentences...
# Entered 34500 sentences...
# Entered 35000 sentences...
# Entered 35500 sentences...
# Entered 36000 sentences...
# Entered 36500 sentences...
# Entered 37000 sentences...
# Entered 37500 sentences...
# Entered 38000 sentences...
# Entered 38500 sentences...
# Entered 39000 sentences...
# Entered 39500 sentences...
# Entered 40000 sentences...
# Entered 40500 sentences...
# Entered 41000 sentences...
# Entered 41500 sentences...
# Entered 42000 sentences...
# Entered 42500 sentences...
# Entered 43000 sentences...
# Entered 43500 sentences...
# Entered 44000 sentences...
# Entered 44500 sentences...
# Entered 45000 sentences...
# Entered 45500 sentences...
# Entered 46000 sentences...
# Entered 46500 sentences...
# Entered 47000 sentences...
# Entered 47500 sentences...
# Entered 48000 sentences...
# Entered 48500 sentences...
# Entered 49000 sentences...
# Entered 49500 sentences...
# Entered 50000 sentences...
# Entered 50500 sentences...
# Entered 51000 sentences...
# Entered 51500 sentences...
# Entered 52000 sentences...
# Entered 52500 sentences...
# Entered 53000 sentences...
# Entered 53500 sentences...
# Entered 54000 sentences...
# Entered 54500 sentences...
# Entered 55000 sentences...
# Entered 55500 sentences...
# Entered 56000 sentences...
# Entered 56500 sentences...
# Entered 57000 sentences...
# Entered 57500 sentences...
# Entered 58000 sentences...
# Entered 58500 sentences...
# Entered 59000 sentences...
# Entered 59500 sentences...
# Entered 60000 sentences...
# Entered 60500 sentences...
# Entered 61000 sentences...
# Entered 61500 sentences...
# Entered 62000 sentences...
# Entered 62500 sentences...
# Entered 63000 sentences...
# Entered 63500 sentences...
# Entered 64000 sentences...
# Entered 64500 sentences...
# Entered 65000 sentences...
# Entered 65500 sentences...
# Entered 66000 sentences...
# Entered 66500 sentences...
# Entered 67000 sentences...
# Entered 67500 sentences...
# Entered 68000 sentences...
# Entered 68500 sentences...
# Entered 69000 sentences...
# Entered 69500 sentences...
# Entered 70000 sentences...
# Entered 70500 sentences...
# Entered 71000 sentences...
# Entered 71500 sentences...
# Entered 72000 sentences...
# Entered 72500 sentences...
# Entered 73000 sentences...
# Entered 73500 sentences...
# Entered 74000 sentences...
# Entered 74500 sentences...
# Entered 75000 sentences...
# Entered 75500 sentences...
# Entered 76000 sentences...
# Entered 76500 sentences...
# Entered 77000 sentences...
# Entered 77500 sentences...
# Entered 78000 sentences...
# Entered 78500 sentences...
# Entered 79000 sentences...
# Entered 79500 sentences...
# Entered 80000 sentences...
# Entered 80500 sentences...
# Entered 81000 sentences...
# Entered 81500 sentences...
# Entered 82000 sentences...
# Entered 82500 sentences...
# Entered 83000 sentences...
# Entered 83500 sentences...
# Entered 84000 sentences...
# Entered 84500 sentences...
# Entered 85000 sentences...
# Entered 85500 sentences...
# Entered 86000 sentences...
# Entered 86500 sentences...
# Entered 87000 sentences...
# Entered 87500 sentences...
# Entered 88000 sentences...
# Entered 88500 sentences...
# Entered 89000 sentences...
# Entered 89500 sentences...
# Entered 90000 sentences...
# Entered 90500 sentences...
# Entered 91000 sentences...
# Entered 91500 sentences...
# Entered 92000 sentences...
# Entered 92500 sentences...
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...
# Entered 3000 sentences...
# Entered 3500 sentences...
# Entered 4000 sentences...
# Entered 4500 sentences...
# Entered 5000 sentences...
# Entered 5500 sentences...
# Entered 6000 sentences...
# Entered 6500 sentences...
# Entered 7000 sentences...
# Entered 7500 sentences...
# Entered 8000 sentences...
# Entered 8500 sentences...
# Entered 9000 sentences...
# Entered 9500 sentences...
# Entered 10000 sentences...
# Entered 10500 sentences...
# Entered 11000 sentences...
# Entered 11500 sentences...
# Entered 12000 sentences...
# Entered 12500 sentences...
# Entered 13000 sentences...
# Entered 13500 sentences...
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...
# Entered 3000 sentences...
# Entered 3500 sentences...
# Entered 4000 sentences...
# Entered 4500 sentences...
# Entered 5000 sentences...
# Entered 5500 sentences...
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...
# Entered 3000 sentences...
# Entered 3500 sentences...
# Entered 4000 sentences...
# Entered 4500 sentences...
# Entered 5000 sentences...
# Entered 5500 sentences...
# Entered 6000 sentences...
# Entered 6500 sentences...
# Entered 7000 sentences...
# Entered 7500 sentences...
# Entered 8000 sentences...
# Entered 8500 sentences...
# Entered 9000 sentences...
# Entered 9500 sentences...
# Entered 10000 sentences...
# Entered 10500 sentences...
# Entered 11000 sentences...
# Entered 11500 sentences...
# Entered 12000 sentences...
# Entered 12500 sentences...
# Entered 13000 sentences...
# Entered 13500 sentences...
# Entered 14000 sentences...
# Entered 14500 sentences...
# Entered 15000 sentences...
# Entered 15500 sentences...
# Entered 16000 sentences...
# Entered 16500 sentences...
# Entered 17000 sentences...
# Entered 17500 sentences...
# Entered 18000 sentences...
# Entered 18500 sentences...
# Entered 19000 sentences...
# Entered 19500 sentences...
# Entered 0 sentences...
# Entered 500 sentences...
# Entered 1000 sentences...
# Entered 1500 sentences...
# Entered 2000 sentences...
# Entered 2500 sentences...

# %%
"something something {disfmarker}".replace("{disfmarker}", "")
# Out:
# 'something something '
